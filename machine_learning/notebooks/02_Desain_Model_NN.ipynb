# %% [markdown]
# # Desain Model AI untuk Project SafeFood

# %% [markdown]
# ### **Deskripsi Arsitektur Model Neural Network - SafeFood Project**
#
# 1. **Input Layer**:
#    - Ukuran input layer menyesuaikan dengan jumlah fitur pada dataset latih (`x_train.shape[1]`).
#    - Layer ini menerima data yang sudah melalui preprocessing.
#
# 2. **Hidden Layer**:
#    - **Jumlah Hidden Layer**: 1.
#    - **Jumlah Neuron**: 96 neuron.
#    - **Fungsi Aktivasi**: ReLU (Rectified Linear Unit).
#    - **Dropout**: Dropout layer dengan tingkat dropout sebesar 20% diterapkan setelah hidden layer untuk mencegah overfitting.
#
# 3. **Output Layer**:
#    - **Jumlah Neuron**: 1 neuron (karena ini adalah tugas regresi).
#    - **Fungsi Aktivasi**: Linear (cocok untuk memprediksi nilai kontinu seperti `matching_score`).
#
# 4. **Hyperparameter Model**:
#    - **Loss Function**: Mean Squared Error (MSE).
#      - MSE dipilih karena tugas ini merupakan masalah regresi, di mana kita ingin meminimalkan rata-rata kuadrat dari kesalahan prediksi.
#    - **Optimizer**: Adam Optimizer.
#      - **Learning Rate**: 0.0009686835179818646 (hasil tuning hyperparameter terbaik).
#    - **Metrics**: Mean Absolute Error (MAE) digunakan sebagai metrik evaluasi tambahan untuk memantau performa model selama pelatihan.
#
# 5. **Pengaturan Pelatihan**:
#    - **Batch Size**: 32 (mini-batch stochastic gradient descent).
#    - **Epochs**: Maksimum 50 epoch.
#    - **Callback**: Early Stopping diterapkan dengan konfigurasi:
#      - **Patience**: 5 (pelatihan dihentikan lebih awal jika validasi loss tidak membaik selama 5 epoch berturut-turut).
#      - **Restore Best Weights**: True (mengembalikan bobot model ke kondisi terbaik saat validasi loss terendah).
#
# 6. **Evaluasi dan Penyimpanan**:
#    - Model dievaluasi menggunakan dataset test untuk menghitung `Test Loss` dan `Test MAE`.
#    - Model disimpan dalam format Keras dengan nama `model_safefood_best.keras` di direktori `../models`.
#
# 7. **Visualisasi Hasil Pelatihan**:
#    - **Training vs Validation Loss**: Grafik ditampilkan untuk memantau tren loss selama pelatihan.
#    - **Training vs Validation MAE**: Grafik ditampilkan untuk memantau tren MAE selama pelatihan.
#
# ---
#
# ### **Penjelasan Singkat**
# Model ini dirancang untuk memprediksi nilai **matching_score** berdasarkan atribut donor dan penerima makanan. Dengan arsitektur sederhana (1 hidden layer dengan 96 neuron), model ini menggabungkan dropout untuk regularisasi dan menggunakan optimizer Adam dengan learning rate yang telah dituning.
#
# Desain ini bertujuan untuk memastikan performa yang stabil sambil mencegah overfitting. Model dievaluasi secara menyeluruh menggunakan training, validation, dan test set.

# %% [markdown]
# Import Library yang dibutuhkan :

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

print("Library berhasil diimport")
# Out:
# Library berhasil diimport

# %% [markdown]
# Muat dataset yang diperlukan :

# %%
# Membaca dataset
train_data = pd.read_csv('../data/processed/training_set.csv')
val_data = pd.read_csv('../data/processed/validation_set.csv')
test_data = pd.read_csv('../data/processed/test_set.csv')

# Menghapus kolom yang tidak diperlukan
x_train = train_data.drop(columns=['id_penyumbang', 'id_penerima', 'matching_score'])
y_train = train_data['matching_score']

x_val = val_data.drop(columns=['id_penyumbang', 'id_penerima', 'matching_score'])
y_val = val_data['matching_score']

x_test = test_data.drop(columns=['id_penyumbang', 'id_penerima', 'matching_score'])
y_test = test_data['matching_score']

print("Dataset berhasil diimport")
# Out:
# Dataset berhasil diimport

# %% [markdown]
# Membuat Model :

# %%
# Membuat model dengan arsitektur sesuai dengan hasil hyperparameter terbaik
model = Sequential([
    Input(shape=(x_train.shape[1],)),  # Menyesuaikan ukuran input dengan data fitur
    Dense(96, activation='relu'),  # Layer pertama dengan 96 neuron dan ReLU
    Dropout(0.2),  # Dropout layer dengan tingkat dropout 20%
    Dense(1, activation='linear')  # Output layer dengan 1 neuron untuk regresi
])

print("Model berhasil dibuat")
# Out:
# Model berhasil dibuat

# %% [markdown]
# Mengkompilasi Model :

# %%
# Mengkompilasi model
model.compile(
    loss='mse',  # Mean Squared Error untuk regresi
    optimizer=Adam(learning_rate=0.0009686835179818646),  # Adam optimizer dengan learning rate terbaik
    metrics=['mae']  # Mean Absolute Error untuk evaluasi
)

print("Model berhasil dikompilasi")
# Out:
# Model berhasil dikompilasi

# %% [markdown]
# Melatih Model :

# %%
# Melatih model
history = model.fit(
    x_train, y_train,  # Data latih
    validation_data=(x_val, y_val),  # Data validasi
    epochs=50,  # Maksimum 50 epoch
    batch_size=32,  # Batch size 32
    callbacks=[ 
        tf.keras.callbacks.EarlyStopping(
            patience=5,  # Menghentikan pelatihan jika tidak ada perbaikan selama 5 epoch
            restore_best_weights=True  # Kembali ke bobot terbaik
        )
    ],
    verbose=1  # Menampilkan progres pelatihan
)
# Out:
# Epoch 1/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0567 - mae: 0.1823 - val_loss: 0.0069 - val_mae: 0.0672
# Epoch 2/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0133 - mae: 0.0916 - val_loss: 0.0044 - val_mae: 0.0531
# Epoch 3/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0085 - mae: 0.0731 - val_loss: 0.0037 - val_mae: 0.0489
# Epoch 4/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0067 - mae: 0.0646 - val_loss: 0.0036 - val_mae: 0.0471
# Epoch 5/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0059 - mae: 0.0613 - val_loss: 0.0029 - val_mae: 0.0427
# Epoch 6/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0050 - mae: 0.0558 - val_loss: 0.0028 - val_mae: 0.0432
# Epoch 7/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048 - mae: 0.0556 - val_loss: 0.0025 - val_mae: 0.0404
# Epoch 8/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0040 - mae: 0.0503 - val_loss: 0.0024 - val_mae: 0.0392
# Epoch 9/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0038 - mae: 0.0488 - val_loss: 0.0022 - val_mae: 0.0373
# Epoch 10/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0036 - mae: 0.0478 - val_loss: 0.0023 - val_mae: 0.0382
# Epoch 11/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mae: 0.0455 - val_loss: 0.0020 - val_mae: 0.0361
# Epoch 12/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - mae: 0.0442 - val_loss: 0.0019 - val_mae: 0.0354
# Epoch 13/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - mae: 0.0427 - val_loss: 0.0018 - val_mae: 0.0333
# Epoch 14/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - mae: 0.0428 - val_loss: 0.0018 - val_mae: 0.0333
# Epoch 15/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0027 - mae: 0.0414 - val_loss: 0.0017 - val_mae: 0.0333
# Epoch 16/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - mae: 0.0413 - val_loss: 0.0016 - val_mae: 0.0321
# Epoch 17/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - mae: 0.0402 - val_loss: 0.0016 - val_mae: 0.0317
# Epoch 18/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0024 - mae: 0.0394 - val_loss: 0.0016 - val_mae: 0.0311
# Epoch 19/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - mae: 0.0393 - val_loss: 0.0014 - val_mae: 0.0300
# Epoch 20/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - mae: 0.0379 - val_loss: 0.0014 - val_mae: 0.0300
# Epoch 21/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mae: 0.0375 - val_loss: 0.0013 - val_mae: 0.0291
# Epoch 22/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mae: 0.0367 - val_loss: 0.0013 - val_mae: 0.0283
# Epoch 23/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mae: 0.0369 - val_loss: 0.0013 - val_mae: 0.0287
# Epoch 24/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - mae: 0.0354 - val_loss: 0.0013 - val_mae: 0.0290
# Epoch 25/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - mae: 0.0360 - val_loss: 0.0012 - val_mae: 0.0280
# Epoch 26/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - mae: 0.0360 - val_loss: 0.0012 - val_mae: 0.0278
# Epoch 27/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - mae: 0.0346 - val_loss: 0.0012 - val_mae: 0.0276
# Epoch 28/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - mae: 0.0350 - val_loss: 0.0013 - val_mae: 0.0292
# Epoch 29/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - mae: 0.0342 - val_loss: 0.0012 - val_mae: 0.0279
# Epoch 30/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018 - mae: 0.0339 - val_loss: 0.0012 - val_mae: 0.0284
# Epoch 31/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - mae: 0.0337 - val_loss: 0.0010 - val_mae: 0.0256
# Epoch 32/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018 - mae: 0.0337 - val_loss: 0.0011 - val_mae: 0.0262
# Epoch 33/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - mae: 0.0330 - val_loss: 0.0011 - val_mae: 0.0267
# Epoch 34/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - mae: 0.0336 - val_loss: 9.9675e-04 - val_mae: 0.0253
# Epoch 35/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - mae: 0.0329 - val_loss: 9.9979e-04 - val_mae: 0.0251
# Epoch 36/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - mae: 0.0330 - val_loss: 0.0012 - val_mae: 0.0268
# Epoch 37/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - mae: 0.0325 - val_loss: 0.0010 - val_mae: 0.0260
# Epoch 38/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mae: 0.0320 - val_loss: 0.0010 - val_mae: 0.0258
# Epoch 39/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mae: 0.0319 - val_loss: 9.4731e-04 - val_mae: 0.0248
# Epoch 40/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mae: 0.0318 - val_loss: 0.0010 - val_mae: 0.0255
# Epoch 41/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - mae: 0.0324 - val_loss: 9.6746e-04 - val_mae: 0.0250
# Epoch 42/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - mae: 0.0322 - val_loss: 9.4307e-04 - val_mae: 0.0249
# Epoch 43/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mae: 0.0319 - val_loss: 9.7954e-04 - val_mae: 0.0253
# Epoch 44/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - mae: 0.0321 - val_loss: 9.3563e-04 - val_mae: 0.0245
# Epoch 45/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mae: 0.0319 - val_loss: 9.6359e-04 - val_mae: 0.0252
# Epoch 46/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - mae: 0.0308 - val_loss: 0.0010 - val_mae: 0.0251
# Epoch 47/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - mae: 0.0323 - val_loss: 9.7591e-04 - val_mae: 0.0253
# Epoch 48/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mae: 0.0310 - val_loss: 0.0011 - val_mae: 0.0264
# Epoch 49/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mae: 0.0320 - val_loss: 8.9422e-04 - val_mae: 0.0240
# Epoch 50/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mae: 0.0314 - val_loss: 9.3164e-04 - val_mae: 0.0245

# %% [markdown]
# Menampilkan Plot :

# %%
# Plot Loss selama Pelatihan
plt.figure(figsize=(12, 6))

# Plot training loss
plt.plot(history.history['loss'], label='Training Loss')
# Plot validation loss
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot MAE selama Pelatihan
plt.figure(figsize=(12, 6))

# Plot training MAE
plt.plot(history.history['mae'], label='Training MAE')
# Plot validation MAE
plt.plot(history.history['val_mae'], label='Validation MAE')

plt.title('Training and Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.grid(True)
plt.show()

print("Model berhasil dilatih")
# Out:
# Model berhasil dilatih

# %% [markdown]
# Evaluasi Model :

# %%
# Evaluasi pada dataset test
test_loss, test_mae = model.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7986e-04 - mae: 0.0241
# Test Loss: 0.0008574620587751269, Test MAE: 0.02374442294239998

# %% [markdown]
# Menyimpan Model :

# %%
# Menyimpan model
model.save("../models/model_safefood_best.keras")
print("Model berhasil disimpan")
# Out:
# Model berhasil disimpan
